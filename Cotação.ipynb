# %% [markdown]
# <h2>Bem vindo a cotação automática ! <h2>

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

from datetime import datetime, timedelta
import time
import calendar

site = "http://hindalco.simfrete.com.br/"

#Dados Gerais
Cidade_Origem = str(input('DADOS GERAIS:\n\nCidade de Origem: '))
Estado_Origem = str(input('Estado de Origem: '))
Cidade_Destino = str(input('Cidade de Destino: '))
Estado_Destino = str(input('Estado de Destino: '))
Transportadora = str(input('Transportadora: '))
Peso = int(input('Peso em Toneladas: '))
Incoterm = str(input('Incoterm: '))

# %%
#Frete Peso
Acima_de = str(input('\n\n\nFRETE PESO:\n\nAcima de: '))
Custo_peso_extra = str(input('Kg,R$: '))
Frete_peso_minimo = str(input('Taxa R$: '))

#Frete Valor
Valor_Frete_Min = str(input('\n\n\nFRETE VALOR:\n\nDe R$(>): '))
percentual_valor = str(input('Percentual(%): '))
Frete_Valor = str(input('Valor(R$): '))

#Generalidades
GRIS_Ate = str(input('\n\n\nGENERALIDADES:\n\nAté R$: '))
GRIS_Percentual_1 = str(input('Percentual: '))
GRIS_Percentual_2 = str(input('Percentual: '))
GRIS_Minimo = str(input('Gris mínimo: '))
Reentrega_Percentual = str(input('Reentrega percentual: '))
Reentrega_Minima = str(input('Reentrega Minima: '))
Devolucao_Percentual = str(input('Devolução percentual: '))
Devolucao_Minima = str(input('Devolução Mínima: '))

Taxa_Pedagio =  str(input('\nTaxa Pedágio\nTaxa R$: '))

Nome_Tabela = (Transportadora+' - '+Cidade_Origem+'/'+ Estado_Origem + ' X ' + Cidade_Destino + '/' + Estado_Destino + ' - ' + str(Peso) + 'T')

#Dia de criação da tabela
Hoje = datetime.today()
Hoje_str = (str(Hoje.day)+'/0'+str(Hoje.month)+'/'+str(Hoje.year))

#Vencimento
Vencimento = Hoje + timedelta(days=180)
Vencimento_str = (str(Vencimento.day)+'/'+str(Vencimento.month)+'/'+str(Vencimento.year))
# Out:
# FRETE PESO:
#
# Acima de: 0
# Kg,R$: 0
# Taxa R$: 0
#
#
#
# FRETE VALOR:
#
# De R$(>): 0
# Percentual(%): 0
# Valor(R$): 0
#
#
#
# GENERALIDADES:
#
# Até R$: 0
# Percentual: 0
# Percentual: 0
# Gris mínimo: 0
# Reentrega percentual: 0
# Reentrega Minima: 0
# Devolução percentual: 0
# Devolução Mínima: 0
#
# Taxa Pedágio
# Taxa R$: 0

# %%
navegador = webdriver.Chrome()

def get(x):
    navegador.get(x)
    
def clicar(Xpath):
    navegador.find_element_by_xpath(Xpath).click()

def Escrever(Xpath,dizer):
    Text = navegador.find_element_by_xpath(Xpath)
    Text.click()
    Text.send_keys(dizer)

#Chama o site
get(site)

#Acessar sistema de gestão
Sistema_de_gestao = '/html/body/table[2]/tbody/tr[1]/td/div/div/p[1]/a'
clicar(Sistema_de_gestao)

#Confirmar segurança
Ocultar_Detalhes = '/html/body/div/div[2]/button[3]'
clicar(Ocultar_Detalhes)
Permitir_Acesso = '/html/body/div/div[3]/p[2]/a'
clicar(Permitir_Acesso)

#Empresa
empresa = '/html/body/table[2]/tbody/tr[1]/td/div/center/form/table/tbody/tr[2]/td/input'
Escrever(empresa,'hindalco')

# #Usuário
usuario = '/html/body/table[2]/tbody/tr[1]/td/div/center/form/table/tbody/tr[3]/td/input'
Escrever(usuario,'gabriel.senra')

#Senha
senha = '/html/body/table[2]/tbody/tr[1]/td/div/center/form/table/tbody/tr[4]/td/input'
Escrever(senha,'12345678')

#Entrar
entrar = ''
navegador.find_element_by_xpath('/html/body/table[2]/tbody/tr[1]/td/div/center/form/table/tbody/tr[5]/td/input').click()

#Cadastro
cadastro = ''
time.sleep(1)
navegador.find_element_by_xpath('/html/body/table[1]/tbody/tr/td[2]/div/table/tbody/tr/td[1]/div/table/tbody/tr/td[4]').click()

#Tabela de frete
tabela_frete = ''
navegador.find_element_by_xpath('/html/body/div[1]/div/table/tbody/tr[2]/td[2]/div/div/table/tbody/tr[2]/td').click()

#Nova Tabela
time.sleep(1)
nova_tabela = ''
navegador.find_element_by_xpath('/html/body/table[2]/tbody/tr[1]/td/div/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[1]/td/table/tbody/tr/td/table/tbody/tr[2]/td/table/tbody/tr/td[4]/button').click()

#Nome da tabela
time.sleep(1)
nome_tabela = ''
Text_area = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr/td/table/tbody/tr[2]/td[2]/input')
Text_area.click()
Text_area.send_keys(Nome_Tabela)

#Coleta somente nas cidades
coleta_cidade = ''
navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr/td/table/tbody/tr[6]/td[2]/table/tbody/tr[1]/td/select').click()
navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr/td/table/tbody/tr[6]/td[2]/table/tbody/tr[1]/td/select/option[2]').click()

#Destino
destino = ''
Text_area = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr/td/table/tbody/tr[7]/td[2]/table/tbody/tr[1]/td/table/tbody/tr/td/select')
Text_area.click()
Text_area.send_keys(Estado_Destino)

#Entrega somente nas cidades
entrega = ''
navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr/td/table/tbody/tr[7]/td[2]/table/tbody/tr[2]/td/select').click()
navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr/td/table/tbody/tr[7]/td[2]/table/tbody/tr[2]/td/select/option[2]').click()

#Modal
modal = ''
navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr/td/table/tbody/tr[8]/td[2]/table/tbody/tr/td[2]/table/tbody/tr/td/select').click()
navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr/td/table/tbody/tr[8]/td[2]/table/tbody/tr/td[2]/table/tbody/tr/td/select/option[4]').click()

#Natureza do transporte
if Incoterm == 'CIF':
    box1 = ''
    box2 = ''
    box3 = ''
    navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr/td/table/tbody/tr[9]/td[2]/table/tbody/tr[1]/td[1]/span/input').click()
    navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr/td/table/tbody/tr[9]/td[2]/table/tbody/tr[2]/td[1]/span/input').click()
    navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr/td/table/tbody/tr[9]/td[2]/table/tbody/tr[2]/td[2]/span/input').click()
    
    navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr/td/table/tbody/tr[10]/td[2]/table/tbody/tr/td[1]/span/input').click()
elif Incoterm == 'FOB':
    box1 = ''
    box2 = ''
    box3 = ''
    navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr/td/table/tbody/tr[9]/td[2]/table/tbody/tr[1]/td[2]/span/input').click()
    navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr/td/table/tbody/tr[9]/td[2]/table/tbody/tr[2]/td[1]/span/input').click()
    navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr/td/table/tbody/tr[9]/td[2]/table/tbody/tr[2]/td[2]/span/input').click()

    navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr/td/table/tbody/tr[10]/td[2]/table/tbody/tr/td[2]/span/input').click()
    
#Validade da tabela
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr/td/table/tbody/tr[12]/td[2]/table/tbody/tr/td[2]/table/tbody/tr/td[1]/input')
Text.click()
Text.send_keys(Hoje_str)

Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr/td/table/tbody/tr[12]/td[2]/table/tbody/tr/td[4]/table/tbody/tr/td[1]/input')
Text.click()
Text.send_keys(Vencimento_str)

#Frete Peso
frete_peso = '/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[1]/td/table/tbody/tr/td[3]/div/div'
clicar(frete_peso)
#Adicionar
adicionar = '/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[2]/table/tbody/tr[4]/td/table/tbody/tr/td/table/tbody/tr[1]/td[8]/button/table/tbody/tr/td[2]'
clicar(adicionar)

#De KG(>)
De_KG = ''
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[2]/table/tbody/tr[4]/td/table/tbody/tr/td/table/tbody/tr[2]/td[2]/div/input')
Text.click()
Text.send_keys('0')

#Sel Tx
Sel = ''
navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[2]/table/tbody/tr[4]/td/table/tbody/tr/td/table/tbody/tr[2]/td[6]/span/input').click()

#Acima de
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[2]/table/tbody/tr[5]/td/table/tbody/tr/td[2]/div/input')
Text.click()
Text.send_keys(Acima_de)
#Taxa kg,rs
taxa_kg_rs = ''
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[2]/table/tbody/tr[5]/td/table/tbody/tr/td[4]/div/input')
Text.click()
Text.send_keys(Custo_peso_extra)

#Frete Minimo
frete_minimo = ''
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[2]/table/tbody/tr[4]/td/table/tbody/tr/td/table/tbody/tr[2]/td[7]/div/input')
Text.click()
Text.send_keys(Frete_peso_minimo)

#Frete Valor
navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[1]/td/table/tbody/tr/td[4]/div/div').click()

#Adicionar
navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[3]/table/tbody/tr[3]/td/table/tbody/tr/td/table/tbody/tr/td[6]/button/table/tbody/tr/td[2]').click()

#De R$ (>)
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[3]/table/tbody/tr[3]/td/table/tbody/tr/td/table/tbody/tr[2]/td[2]/div/input')
Text.click()
Text.send_keys(Valor_Frete_Min)

#Percentual (%)
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[3]/table/tbody/tr[3]/td/table/tbody/tr/td/table/tbody/tr[2]/td[4]/div/input')
Text.click()
Text.send_keys(percentual_valor)

#Valor (R$)
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[3]/table/tbody/tr[3]/td/table/tbody/tr/td/table/tbody/tr[2]/td[5]/div/input')
Text.click()
Text.send_keys(Frete_Valor)

#Acima de R$
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[3]/table/tbody/tr[4]/td/table/tbody/tr/td[2]/div/input')
Text.click()
Text.send_keys('0')

#cobrar
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[3]/table/tbody/tr[4]/td/table/tbody/tr/td[4]/div/input')
Text.click()
Text.send_keys('0')

#Generalidades
navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[1]/td/table/tbody/tr/td[8]/div/div').click()

#ICMS
#Incotem
if Incoterm == 'CIF':
    navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[1]/td[2]/table/tbody/tr[1]/td/span/input').click()
elif Incoterm == 'FOB':
    navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[1]/td[2]/table/tbody/tr[2]/td/span/input').click()
    
#PIS/Confins
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[1]/td[4]/table/tbody/tr[1]/td/table/tbody/tr/td[1]/div/input')
Text.click()
Text.send_keys('0')

#GRIS
#Até R$
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[2]/td[2]/table/tbody/tr[1]/td[2]/div/input')
Text.click()
Text.send_keys(GRIS_Ate)

#percentual1
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[2]/td[2]/table/tbody/tr[1]/td[4]/div/input')
Text.click()
Text.send_keys(GRIS_Percentual_1)

#percentual2
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[2]/td[2]/table/tbody/tr[2]/td[4]/div/input')
Text.click()
Text.send_keys(GRIS_Percentual_2)

#Gris Minimo
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[2]/td[2]/table/tbody/tr[3]/td[3]/div/input')
Text.click()
Text.send_keys(GRIS_Minimo)

#Palets
#Palet1
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[3]/td[2]/table/tbody/tr[1]/td/table/tbody/tr/td[2]/div/input')
Text.click()
Text.send_keys('0')

#Palet2
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[3]/td[2]/table/tbody/tr[2]/td/table/tbody/tr/td[2]/div/input')
Text.click()
Text.send_keys('0')

#Reentrega
#Reentrega%
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[4]/td[2]/table/tbody/tr/td[1]/div/input')
Text.click()
Text.send_keys(Reentrega_Percentual)
#ReentregaMinimo
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[4]/td[2]/table/tbody/tr/td[4]/div/input')
Text.click()
Text.send_keys(Reentrega_Minima)

#Devolução%
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[5]/td[2]/table/tbody/tr/td[1]/div/input')
Text.click()
Text.send_keys(Devolucao_Percentual)
#DevoluçãoMinimo
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[5]/td[2]/table/tbody/tr/td[4]/div/input')
Text.click()
Text.send_keys(Devolucao_Minima)

#Tx Permanencia1
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[6]/td[2]/table/tbody/tr/td[2]/div/input')
Text.click()
Text.send_keys('0')

#Tx Permanencia2
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[6]/td[2]/table/tbody/tr/td[4]/div/input')
Text.click()
Text.send_keys('0')

#Tx Permanencia3
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[6]/td[2]/table/tbody/tr/td[6]/div/input')
Text.click()
Text.send_keys('0')

#Pedágio
navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[1]/td/table/tbody/tr/td[3]/div/div').click()

#Adicionar Base do ICMS
navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[2]/table/tbody/tr[1]/td/table/tbody/tr/td[6]/span/input').click()

#Adicionar
navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[2]/table/tbody/tr[2]/td/table/tbody/tr/td/table/tbody/tr/td[9]/button/table/tbody/tr/td[2]').click()

#Sel Taxa
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[2]/table/tbody/tr[2]/td/table/tbody/tr/td/table/tbody/tr[2]/td[7]/span/input').click()

#Peso De Kg (>)
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[2]/table/tbody/tr[2]/td/table/tbody/tr/td/table/tbody/tr[2]/td[2]/div/input')
Text.click()
Text.send_keys('0')

#Taxa R$
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[2]/table/tbody/tr[2]/td/table/tbody/tr/td/table/tbody/tr[2]/td[8]/div/input')
Text.click()
Text.send_keys(Taxa_Pedagio)

#Acima de
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[2]/table/tbody/tr[3]/td/table/tbody/tr/td[2]/div/input')
Text.click()
Text.send_keys('0')

#Kg, cobrar R$
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[7]/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[2]/table/tbody/tr[3]/td/table/tbody/tr/td[4]/div/input')
Text.click()
Text.send_keys('0')

#Cidades e Destinatários
navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[1]/td/table/tbody/tr/td[10]/div/div').click()

#Origem em
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[9]/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[2]/td/table/tbody/tr[6]/td[2]/table/tbody/tr/td/select')
Text.click()
Text.send_keys(Estado_Origem)

#Destino em
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[9]/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[2]/td/table/tbody/tr[7]/td[2]/table/tbody/tr/td/select')
Text.click()
Text.send_keys(Estado_Destino)

#Peso De (>=)
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[9]/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[2]/td/table/tbody/tr[13]/td[1]/table/tbody/tr/td/table/tbody/tr[2]/td[3]/div/input')
Text.click()
Text.send_keys('0')

#Peso Até (<=)
Text = navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[2]/td/div/div[9]/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr[2]/td/table/tbody/tr[13]/td[1]/table/tbody/tr/td/table/tbody/tr[2]/td[4]/div/input')
Text.click()
Text.send_keys(Peso*1400)

#Dados Gerais
navegador.find_element_by_xpath('/html/body/div[2]/div/table/tbody/tr[2]/td[2]/div/table/tbody/tr[3]/td/table/tbody/tr[1]/td/table/tbody/tr/td[2]/div/div').click()
